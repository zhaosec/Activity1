# %% [markdown]
# <a href="https://colab.research.google.com/github/zhaosec/Activity1/blob/master/Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U "jax[tpu]"

# %%
# !pip install gemma
